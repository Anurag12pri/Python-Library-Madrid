# %%
# Visualizing statistical relationships
# Statistical analysis is a process of understanding how variables in a dataset relate to each other and how those relationships depend on other variables. Visualization can be a core component of this process because, when data are visualized properly, the human visual system can see trends and patterns that indicate a relationship.
# 1. Numerical Data Ploting
# relplot()
# scatterplot()
# lineplot()
# 2. Categorical Data Ploting
# catplot()
# boxplot()
# stripplot()
# swarmplot()
# etc...
# 3. Visualizing Distribution of the Data
# distplot()
# kdeplot()
# jointplot()
# rugplot()
# 4. Linear Regression and Relationship
# regplot()
# lmplot()

# %%
import seaborn as sns
import pandas as pd

# %%
sns.set(style='dark')
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill',y='tip',data=tips,height=7,aspect=3)

# %%
sns.relplot(x='total_bill',y='tip',hue='sex',data=tips,height=4,aspect=3)

# %%
tips['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',hue='size',data=tips,height=6,aspect=2)

# %%
sns.relplot(x='total_bill',y='tip', data=tips,style='size',hue='sex',height=5,aspect=2)

# %%
sns.relplot(x='total_bill',y='tip', data=tips,style='time',hue='smoker', size='size',height=5,aspect=2)

# %%
sns.relplot(x='total_bill',y='tip', hue='smoker', col='sex',data=tips,height=5,aspect=1)

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,6))
sns.scatterplot(x='total_bill',y='tip',data=tips,hue='smoker',size='size',style='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x=tips['sex'])
# Out:
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='sex', ylabel='count'>

# %%
tips['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
sns.catplot(x='day',y='total_bill',data=tips, height=5,aspect=2.5)
# Out:
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.catplot(x='day',y='tip',data=tips,aspect=2.5,hue='sex')
# Out:
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
diamonds=sns.load_dataset('diamonds')
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds['cut'].value_counts()
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
sns.catplot(x='cut',y='price',kind='box',data=diamonds,height=5,aspect=2.5)
# Out:
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.catplot(y='total_bill',x='day',hue='sex',kind='violin',data=tips,height=5,aspect=2.5)
# Out:
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
titanic=pd.read_csv('titanic_train.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.catplot(x = 'Sex', kind = 'count', data = titanic, hue = 'Pclass',height=5,aspect=2.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 sns.catplot(x = 'Sex', kind = 'count', data = titanic, hue = 'Pclass',height=5,aspect=2.5)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:3244, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3241 g = FacetGrid(**facet_kws)
#    3243 # Draw the plot onto the facets
# -> 3244 g.map_dataframe(plot_func, x=x, y=y, hue=hue, **plot_kws)
#    3246 if p.orient == "h":
#    3247     g.set_axis_labels(p.value_label, p.group_label)
#
# File ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py:819, in FacetGrid.map_dataframe(self, func, *args, **kwargs)
# ...

# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('Sample - Superstore Sales (Excel).xls')
df.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3 2010-10-13            Low               6    261.5400
# 1      49       293 2012-10-01           High              49  10123.0200
# 2      50       293 2012-10-01           High              27    244.5700
# 3      80       483 2011-07-10           High              30   4965.7595
# 4      85       515 2010-08-28  Not Specified              19    394.2700
#
#    Discount       Ship Mode     Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.2500       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck   457.8100      208.16  ...        Barry French
# 2      0.01     Regular Air    46.7075        8.69  ...        Barry French
# 3      0.08     Regular Air  1198.9710      195.99  ...       Clay Rozendal
# 4      0.08     Regular Air    30.9400       21.78  ...      Carlos Soltero
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
pip install xlrd
# Out:
#   Cell In[29], line 1
#     pip install xlrd
#         ^
# SyntaxError: invalid syntax

# %%
df['Profit']
# Out:
# 0       -213.2500
# 1        457.8100
# 2         46.7075
# 3       1198.9710
# 4         30.9400
#           ...
# 8394    -323.1800
# 8395      22.2500
# 8396     343.0500
# 8397    -159.2360
# 8398     580.4300
# Name: Profit, Length: 8399, dtype: float64

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'Province', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')

# %%
df.shape
# Out:
# (8399, 21)

# %%
plt.scatter(df.Sales,df.Profit)
plt.xlabel('Sales')
plt.ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %%
sns.relplot(x='Sales',y='Profit',data=df)
plt.show()

# %%
df['Order Priority'].value_counts()
# Out:
# Order Priority
# High             1768
# Low              1720
# Not Specified    1672
# Medium           1631
# Critical         1608
# Name: count, dtype: int64

# %%
sns.countplot(x='Order Priority',data=df)
# Out:
# <Axes: xlabel='Order Priority', ylabel='count'>

# %%
sns.relplot(x='Sales',y='Profit',data=df,hue='Order Priority')

# %%
sns.relplot(x='Sales',y='Profit',data=df,hue='Order Priority',style='Order Priority')

# %%
sns.relplot(x='Sales',y='Profit',data=df,hue='Order Priority',style='Ship Mode')

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Regular Air       6270
# Delivery Truck    1146
# Express Air        983
# Name: count, dtype: int64

# %%
df['Year']=df['Order Date'].dt.year

# %%
df.Year.head()
# Out:
# 0    2010
# 1    2012
# 2    2012
# 3    2011
# 4    2010
# Name: Year, dtype: int32

# %%
df.shape
# Out:
# (8399, 22)

# %%
sns.relplot(x='Year',y='Sales',data=df,kind='line')
# Out:
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.relplot(x='Year',y='Sales',data=df,kind='line',ci=None)
# Out:
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.catplot(x='Ship Mode',y='Profit',data=df)
# Out:
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.catplot(x='Ship Mode',y='Profit',data=df,jitter=False,palette='husl')
# Out:
# C:\Users\Anurag\AppData\Local\Temp\ipykernel_12988\3850681612.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.catplot(x='Ship Mode',y='Profit',data=df,jitter=False,palette='husl')
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.catplot(x='Ship Mode',y='Profit',data=df.query('Profit>1000'),jitter=False)
# Out:
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.catplot(x='Ship Mode',y='Profit',data=df.query('Profit>1000 & Profit <5000'),kind='swarm')
# Out:
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 20.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='Product Category',y='Shipping Cost',data=df,kind='box')

# %%
sns.catplot(x='Product Category',y='Shipping Cost',hue='Ship Mode',data=df,kind='box')

# %%
sns.catplot(x='Product Category',y='Shipping Cost',col='Ship Mode',data=df,kind='box')

# %%
sns.catplot(x='Product Category',y='Shipping Cost',col='Ship Mode',row='Customer Segment',data=df,kind='violin')

# %%
sns.catplot(x='Product Category',y='Sales',data=df,kind='point')

# %%
sns.catplot(x="Product Category",y='Shipping Cost',col='Ship Mode',row='Customer Segment',data=df,kind='point')

# %%
sns.distplot(df.Sales,kde=False)
# Out:
# C:\Users\Anurag\AppData\Local\Temp\ipykernel_12988\625710349.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Sales,kde=False)
# <Axes: xlabel='Sales'>

# %%
sns.distplot(df.Profit)
# Out:
# C:\Users\Anurag\AppData\Local\Temp\ipykernel_12988\4193180350.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Profit)
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Profit', ylabel='Density'>

# %%
sns.distplot(df.Profit,hist=False)
# Out:
# C:\Users\Anurag\AppData\Local\Temp\ipykernel_12988\2293351618.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Profit,hist=False)
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Profit', ylabel='Density'>

# %%
sns.distplot(df.Profit,kde=False,rug=True)
# Out:
# C:\Users\Anurag\AppData\Local\Temp\ipykernel_12988\3691165824.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Profit,kde=False,rug=True)
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Profit'>

# %%
sns.distplot(df.Profit[(df.Region=="West") & (df.Profit>100)],kde=False,rug=True,bins=100)
# Out:
# C:\Users\Anurag\AppData\Local\Temp\ipykernel_12988\2836102118.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Profit[(df.Region=="West") & (df.Profit>100)],kde=False,rug=True,bins=100)
# C:\Users\Anurag\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Profit'>

# %%
pip install pandas-profiling
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/262.6 kB ? eta -:--:--
#    --------------------------------------- 262.6/262.6 kB 16.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    --------- ------------------------------ 1.2/4.7 MB 37.7 MB/s eta 0:00:01
#    -------------------- ------------------- 2.5/4.7 MB 31.5 MB/s eta 0:00:01
#    ------------------------------------ --- 4.3/4.7 MB 34.1 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 30.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/102.4 kB ? eta -:--:--
#    ---------------------------------------- 102.4/102.4 kB 5.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/309.8 kB ? eta -:--:--
#    ---------------------------------------- 309.8/309.8 kB ? eta 0:00:00
# ...

# %%
from ydata_profiling import ProfileReport
prof=ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# C:\Users\Anurag\anaconda3\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: 'Small Business'')
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
pip install ydata-profiling
# Out:
# ...
#      ---------------------------------------- 0.0/125.2 kB ? eta -:--:--
#      --------- ----------------------------- 30.7/125.2 kB 1.4 MB/s eta 0:00:01
#      ------------ ------------------------ 41.0/125.2 kB 495.5 kB/s eta 0:00:01
#      --------------------------- --------- 92.2/125.2 kB 751.6 kB/s eta 0:00:01
#      ------------------------------------ 125.2/125.2 kB 821.0 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/359.5 kB ? eta -:--:--
#    ------------------ -------------------- 174.1/359.5 kB 10.9 MB/s eta 0:00:01
#    ------------------------------------- -- 337.9/359.5 kB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 359.5/359.5 kB 3.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/423.9 kB ? eta -:--:--
#    --------------------------------------- 423.9/423.9 kB 13.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
# ...
